# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import radon, iradon
import random
import tarfile
import pydicom
import dicom
import pandas as pd
import rarfile
import patoolib
import os
import cv2

# %%
data = patoolib.extract_archive('CTBraindata.zip')
# Out:
# patool: Extracting CTBraindata.zip ...
# patool: ... CTBraindata.zip extracted to `CTBraindata1' (local file exists).

# %%
data_dir = 'CTBraindata/202-brain 1X1-84670/'

# %%
theta = np.linspace(0., 180. 100)
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    i = random.randint(0, 40)
    data_dcm = pydicom.dcmread(data_dir + '/' + data[i])
    plt.imshow(data_dcm.pixel_array, cmap = "Greys_r")
plt.show()

# %%
theta = np.linspace(0., 180., 100)
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    i = random.randint(0, 40)
    data_dcm = pydicom.dcmread(data_dir + '/' + data[i])
    plt.imshow(radon(data_dcm.pixel_array, theta, circle = False), cmap = "Greys_r")
plt.show()

# %%
theta = np.linspace(0., 180., 100)
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    i = random.randint(0, 40)
    data_dcm = pydicom.dcmread(data_dir + '/' + data[i])
    sinogram = radon(data_dcm.pixel_array, theta, circle = False)
    plt.imshow(iradon(sinogram, theta, circle = False), cmap = "Greys_r")
plt.show()
